# %% [markdown]
# <a href="https://colab.research.google.com/github/fedorkrikman/september2025/blob/main/12_3_%D0%A1%D0%BE%D0%B7%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_Telegram_%D0%B1%D0%BE%D1%82%D0%B0_%D1%81_%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%D0%BC_aiogram3_%D0%B8_BotFather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Новая презентация (27).png](data:image/png;base64,...)

# %% [markdown]
# **Навигация по уроку**
#
# 1. [Введение в асинхронное программирование](https://colab.research.google.com/drive/1UavHM4i_kgjmdoMxvxac6LuPfVaBXHNA)
# 2. [Знакомство с библиотекой asyncio](https://colab.research.google.com/drive/1t5GZGzV9a3LZ-l_ZsTg9P8l5U-S_wOdh)
# 3. Создание Telegram-бота с использованием aiogram3 и BotFather
# 4. [Домашняя работа](https://colab.research.google.com/drive/1ylF61osqEgPqg4KgfmikbKMAyalhjBqv)

# %% [markdown]
# В данной части урока мы погружаемся в захватывающий мир создания телеграм-ботов и знакомимся с ключевыми концепциями, которые станут основой для нашего погружения в разработку бота с использованием библиотеки aiogram3 и BotFather.
#
# **Зачем создавать телеграм-ботов?**
#
# В наше время телеграм-боты стали неотъемлемой частью цифрового мира, предоставляя разнообразные сервисы и улучшая пользовательский опыт. Боты могут выполнять различные задачи: от автоматизации рутинных действий до предоставления интерактивных игр и обучающих программ. Создание бота - это увлекательная и творческая задача, открывающая множество возможностей для проявления креативности и навыков программирования. Телеграм-боты в последнее время становятся полноценными интерфейсами для предоставления доступа к сервисам. Под телеграмм-ботом может скрываться, не только качественный алгоритм, который выполняет команды пользователя. В настоящее время телеграмм-бот чаще используется как средство взаимодействия компаний со своими клиентами, как сервисы обратной связи, как канал коммуникаций, технической поддержки.
#
# Если вы помните, то ранее мы говорили, для того чтобы "найти бизнес", необходимо искать сервисы в компаниях. Так вот оно! Телеграм-бот - это окно к сервисам компаний. Это именно, то что нам нужно! Если вы видите, что какой-то сервис в компании "хромает", а ваша нейронная сеть может решить проблемы "хромой лошади", то не обязательно писать мобильное приложение или сложный программный продукт. Сначала обучите нейронку, соберите простой каркас телеграм-бота, и у вас уже готовый прототип взаимодействия компании и клиента.

# %% [markdown]
# На этом уроке мы на примере телеграм-бота для проведения квизов (викторин) рассмотрим библиотеку Aiogram, познакомимся с "отцом всех ботов" (BotFather). В ходе урока вы создадите свой первый телеграмм-бот, а вашим домашним заданием будет его доработка до "совершенства". И уже на следующем уроке, ваш телеграм-бот будет наделен искусственным интеллектом!

# %% [markdown]
# ##Знакомство с BotFather

# %% [markdown]
# BotFather - это официальный бот для создания и настройки Telegram-ботов.

# %% [markdown]
# Для создания нового телеграм-бота необходимо выполнить пошагово следующую инструкцию:

# %% [markdown]
# **Шаг 1: Создание нового бота**
# Первым шагом является запуск диалога с BotFather в Telegram. Просто найдите его в списке контактов и начните чат. Для этого в окне поиска вашего телеграмм введите `@BotFather`.
#
# ![image.png](data:image/png;base64,...)
#
#
# Как только вы запустили чат, используйте команду `/newbot`, чтобы создать нового бота. BotFather будет вести вас через несколько простых шагов, включая выбор уникального имени для вашего бота.
#
# Система попросит указать название бота, а после запросит username, при этом BotFather сразу предупреждает, что юзернейм бота должен заканчиваться на слово bot. Например, TetrisBot или tetris_bot.
#
# В случае успеха, мы увидим сообщение о том, что наш бот создан и готов к работе.
#
#
#
# **Шаг 2: Получение токена**
# После успешного завершения процесса создания бота, BotFather предоставит вам уникальный токен. Сохраните этот токен, он понадобится для взаимодействия с API Telegram. Токен является своего рода цифровым подписыванием вашего бота. Подобно ключу к замку, он позволяет вашему боту отправлять и принимать команды через Telegram API. Без этого ключа ваш бот не сможет функционировать, так как Telegram не сможет идентифицировать его в потоке команд.
#
# **Шаг 3: Настройка бота**
# BotFather также предоставляет вам несколько команд для настройки вашего бота. Вы можете изменить описание бота, добавить фотографию, а также создать свои собственные команды. Эти параметры помогут придать вашему боту уникальную идентичность, а также упростят взаимодействие с ним.
#
# Вы всегда можете запросить список, созданных вами ботов, вызвав команду `\mybots`.
#
# Остались вопросы как создать новый бот? Ознакомьтесь с официальной документацией по [@BotFather](https://core.telegram.org/bots/features#creating-a-new-bot).

# %% [markdown]
# ###Практическое задание

# %% [markdown]
# Для дальнейшего прохождения урока, вам необходимо создать своего бота по инструкции выше.
#
# От вас требуется:
# 1. Создать своего собственного бота в BotFather.
# 2. Придумать ему имя, исходя из того что это будет квиз с вопросами и ответами.
# 3. Получить токен.
# 4. Произвести базовую настройку (добавить описание, картинку).

# %% [markdown]
# ##Знакомство с библиотекой Aiogram 3

# %% [markdown]
# Прежде всего, давайте разъясним, что такое aiogram3 и почему мы выбрали именно эту библиотеку для создания нашего Telegram бота. **Aiogram3** — это библиотека на языке программирования Python, созданная специально для работы с Telegram API. Она обеспечивает удобный и эффективный способ создания ботов, делая процесс взаимодействия с API простым и интуитивно понятным. А самое главное, что она асинхронная!

# %% [markdown]
# Первым шагом для начала работы с aiogram3 является его установка. Для этого мы будем использовать инструмент pip — менеджер пакетов для Python.
#
# Выполните следующую команду:

# %%
# !pip install aiogram
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...

# %% [markdown]
# Добавим код из предыдущего Блокнота, так как в Colab'e уже запущен event loop

# %%
# Установим библиотеку nest_asyncio
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# После установки aiogram3, давайте создадим базовый скрипт, который позволит нам проверить, что библиотека работает корректно:

# %%
import asyncio
import logging
from aiogram import Bot, Dispatcher, types
from aiogram.filters.command import Command

# Включаем логирование, чтобы не пропустить важные сообщения
logging.basicConfig(level=logging.INFO)

# Замените "YOUR_BOT_TOKEN" на токен, который вы получили от BotFather
API_TOKEN = 'YOUR_BOT_TOKEN'


# Объект бота
bot = Bot(token=API_TOKEN)
# Диспетчер
dp = Dispatcher()

# Хэндлер на команду /start
@dp.message(Command("start"))
async def cmd_start(message: types.Message):
    await message.answer("Привет! Я твой новый бот.")

# Запуск процесса поллинга новых апдейтов
async def main():
    await dp.start_polling(bot)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# WARNING:aiogram.dispatcher:Received SIGINT signal

# %% [markdown]
# Обратите внимание, что в коде присутствует строка `API_TOKEN = 'YOUR_BOT_TOKEN'`. Замените `'YOUR_BOT_TOKEN'` на токен, который вы получили от BotFather при создании вашего бота. Этот токен является ключом к вратам вашего бота в Telegram API, и без него бот не сможет функционировать.
#
# Запустив код выше, вы фактически запустили бесконечный асихронный цикл, который будет опрашивать ваш телеграм-бот на наличие апдейтов (обновлений, изменений). Можете запускать ваш чат бот. При нажатии кнопки "Запустить", выполниться команда `\start`. Наш код пока что умеет только эту команду обрабатывать приветствием: "Привет! Я твой новый бот."

# %% [markdown]
# Aiogram основывается на концепции хендлеров для обработки входящих событий. Хендлеры представляют собой функции, которые вызываются при определенных событиях, таких как получение сообщения или нажатие на кнопку. Для создания хендлера используется декоратор `@dp.message()`.

# %% [markdown]
# ###Создание бота

# %% [markdown]
# Создайте новый Colab. Перенесите в него код шаблон выше и будем наполнять его новым функционалом. Если у вас возникнут проблемы со сборкой из блоков конечного бота, то внизу Colab прилагаем полный код бота для самоконтроля.

# %% [markdown]
# Перейдем к написанию телеграм-бота для проведения квиза. Мы выбрали квизы в качестве примера из той логики, что формат вопрос-ответ, по своей сути очень похож на логику работы классического чат-бота или ассистента. Освоив квиз, вы с легкостью сможете перейти к более сложным реализациям ботов, которые могут вести диалоги с пользователем, всего лишь заменив "алгоритмическую начинку" на интеллектуальную.
#
# И так, приступим.
#
# Определим два командных хендлера для `/start` и `/quiz`. Когда пользователь отправляет одну из этих команд, соответствующие хендлеры выполняются.

# %%
# Хэндлер на команду /start
@dp.message(Command("start"))
async def cmd_start(message: types.Message):
    # Логика обработки команды /start
    await message.answer("Привет! Я бот для проведения квиза. Введите /quiz, чтобы начать.")

# Хэндлер на команду /quiz
@dp.message(Command("quiz"))
async def cmd_quiz(message: types.Message):
    # Логика начала квиза
    await message.answer("Давайте начнем квиз! Первый вопрос: ...")

# %% [markdown]
# В aiogram хендлеры используются для реагирования на различные события, такие как получение сообщений или нажатие на кнопки. Основной идеей является создание функций, которые будут вызываться при определенных событиях.
#
# Командные хендлеры используются для обработки ввода команд. Например, при вводе команды /start, будет вызван соответствующий хендлер.

# %% [markdown]
# ### Структуру квиза

# %% [markdown]
# Для простоты реализации, вопросы и ответы квиза будем хранить в переменной quiz_data. Структура представляет собой словари с вопросами, вложенными в список. Каждый словарь имеет 3 ключа:
# * question - вопрос
# * options  - варианты ответов
# * correct_option - индекс правильного ответа

# %%
# Структура квиза
quiz_data = [
    {
        'question': 'Что такое Python?',
        'options': ['Язык программирования', 'Тип данных', 'Музыкальный инструмент', 'Змея на английском'],
        'correct_option': 0
    },
    {
        'question': 'Какой тип данных используется для хранения целых чисел?',
        'options': ['int', 'float', 'str', 'natural'],
        'correct_option': 0
    },
    # Добавьте другие вопросы
]

# %% [markdown]
# Доступ к вопросам квиза будет осуществляется по индексу, хранящему в переменной `current_question_index`. Так как пользователь может бросить прохождение квиза в любой момент и вернуться к нему позже, то нам необходимо хранить последний вопрос, на котором он остановился. В этом случае, нам важно сохранить результат. Мы можем сохранить его в файл, но запись в файл - это блокирующая команда, а мы для себя выбрали асинхронное программирование. Поэтому стоит посмотреть в сторону aiosqlite - асинхронная библиотека для простейшей файловой базы данных SQLite.
#
# Наше знакомство с базами данных будет постепенным и поверхностным, и лишь в тех объемах, которые позволят нам продвигаться дальше по курсу и решать реальные практические задачи.
#
# Для начала необходимо установить библиотеку aiosqlite.

# %%
# !pip install aiosqlite

# %% [markdown]
# ### Проектируем асинхронную базу данных

# %% [markdown]
# Для начала нам необходимо создать таблицу, если она еще не существует. В случае с нашим ботом, действие логично это выполнить в самом начале функции main().

# %%
import aiosqlite

async def create_table():
    # Создаем соединение с базой данных (если она не существует, то она будет создана)
    async with aiosqlite.connect('quiz_bot.db') as db:
        # Выполняем SQL-запрос к базе данных
        await db.execute('''CREATE TABLE IF NOT EXISTS quiz_state (user_id INTEGER PRIMARY KEY, question_index INTEGER)''')
        # Сохраняем изменения
        await db.commit()

# Запускаем создание таблицы базы данных
await create_table()

# %% [markdown]
# С базой данных общаются с помощью SQL-запросов.
#
# Для того, чтобы создать таблицу в SQL, используется выражение `CREATE TABLE`. Он принимает в качестве параметров все колонки, которые мы хотим внести, а также их типы данных.
#
# ```
# CREATE TABLE IF NOT EXISTS quiz_state (user_id INTEGER PRIMARY KEY, question_index INTEGER)
# ```
#
# Таким образом, мы создаем таблицу с названием `quiz_state`, в которой две колонки:
#
# - **user_id** - уникальный идентификатор пользователя в телеграм (целочисленный тип)
# - **question_index** - индекс вопроса, на котором остановился пользователь (целочисленный тип)
#
# Также, когда создаются таблицы, принято добавлять так называемый `primary key`. Это колонка, значения в которой уникальны. Чаще всего `primary key` колонкой является `id`, но в нашем случае это будет `user_id`, так как в телеграм все пользователи уже уникальны.
#
# Конструкция `IF NOT EXISTS` используется с целью проверки условия - существует ли уже таблица, прежде чем пытаться ее создавать.

# %% [markdown]
# Запрос к базе данных осуществляется с помощью асинхронного метода `await db.execute()`.
#
# Если запрос изменяет данные в базе данных, то по его завершению принято вызывать асинхронный метод `await db.commit()` для фиксации изменений.

# %% [markdown]
# Далее нам необходимо добавить в базу нового пользователя и увеличивать значение `question_index` на единицу, после прохождения каждого вопроса квиза пользователем. Для этого мы могли бы использовать 2 запроса `INSERT` и `UPDATE`. `INSERT` выполнили бы один раз при старте квиза, а после каждого вопроса обновляли бы `question_index` с помощью запроса `UPDATE`.
#
# Однако богатый язык SQL предоставляет нам и более элегантные решения:

# %%
async def update_quiz_index(user_id, index):
    # Создаем соединение с базой данных (если она не существует, она будет создана)
    async with aiosqlite.connect(DB_NAME) as db:
        # Вставляем новую запись или заменяем ее, если с данным user_id уже существует
        await db.execute('INSERT OR REPLACE INTO quiz_state (user_id, question_index) VALUES (?, ?)', (user_id, index))
        # Сохраняем изменения
        await db.commit()

# %% [markdown]
# Выше мы написали функцию, которая при первом вызове, для заданного пользователя, создаст запись в таблице `quiz_state`, а при повторном, когда существует запись с заданным `user_id`, заменит ее на новую, обновив при этом `question_index`. В примере видно, что `db.execute` имеет 2 аргумента: текстовый шаблон сообщения и кортеж из параметров. Каждый из этих параметров кортежа, во время выполнения метода, подставляется, в том порядке, в котором он записан, в текстовый шаблон на место знака `?`.
#
# В классическом виде наш запрос на вставку выглядел бы следующим образом:
#
# ```
# INSERT INTO quiz_state (user_id, question_index) VALUES (33, 0)
#
# ```
#
# Таким образом, сразу же за именем таблицы `quiz_state` в запросе, мы указываем в скобках список названий колонок для записи, а после ключевого слова `VALUE` - список значений для этих колонок, также в скобках. Число элементов в скобках должно совпадать. Если мы не указали колонку, то ей будет присвоено значение NULL или заданное значение по умолчанию (указывается при создании таблицы).
#
# Раз мы данные изменяем в таблице, то не забываем фиксировать изменения `await db.commit()`.

# %% [markdown]
# Также нам нужна функция, которая получит текущее значение `question_index` в базе данных для заданного пользователя.

# %%
async def get_quiz_index(user_id):
     # Подключаемся к базе данных
     async with aiosqlite.connect(DB_NAME) as db:
        # Получаем запись для заданного пользователя
        async with db.execute('SELECT question_index FROM quiz_state WHERE user_id = (?)', (user_id, )) as cursor:
            # Возвращаем результат
            results = await cursor.fetchone()
            if results is not None:
                return results[0]
            else:
                return 0

# %% [markdown]
# SQL-запросы на выборку данных с `SELECT` - это самый популярный из запросов. Ни одно приложение не обходится без него. Общую структуру `SELECT` запроса можно представить следующим образом:
#
# ```
# SELECT ('столбцы или * для выбора всех столбцов; обязательно')
# FROM ('таблица; обязательно')
# WHERE ('условие/фильтрация, например, city = 'Moscow'; необязательно')
# GROUP BY ('столбец, по которому хотим сгруппировать данные; необязательно')
# HAVING ('условие/фильтрация на уровне сгруппированных данных; необязательно')
# ORDER BY ('столбец, по которому хотим отсортировать вывод; необязательно')
#
# ```

# %% [markdown]
# `SELECT`, `FROM` — обязательные элементы запроса, которые определяют выбранные столбцы, их порядок и источник данных.
#
# `WHERE` — необязательный элемент запроса, который используется, когда нужно отфильтровать данные по нужному условию. Очень часто внутри элемента `WHERE` используются IN / NOT IN для фильтрации столбца по нескольким значениям, AND / OR для фильтрации таблицы по нескольким столбцам.
#
# В нашем случае, с помощью `WHERE`, мы фильтруем один столбец `user_id` по одному значению, переданному как аргумент в асинхронную функцию `get_quiz_index`.

# %% [markdown]
# В асинхронном взаимодействии с базой данных, библиотека aiosqlite предоставляет асинхронные методы для выполнения SQL-запросов и получения результатов. Один из способов выполнения запроса - это использование объекта `cursor`, который представляет собой курсор, указывающий на результаты запроса.
#
# В функции `get_quiz_index()` используется cursor для выполнения SQL-запроса с отбором по заданному `user_id`. Затем метод `fetchone()` вызывается на объекте `cursor` для получения одной строки результата запроса. Этот метод возвращает кортеж с данными первой строки (если она существует) или None, если результаты отсутствуют. Так как у нас всего одна колонка, то нас из результата интересует только нулевой элемент кортежа.
#
# Если бы нам были нужны все записи, то мы бы использовали `fetchall()`.

# %% [markdown]
# ### Кнопки в телеграм боте

# %% [markdown]
# В нашем примере мы будем использовать 2 вида кнопок.

# %% [markdown]
# Первый вид кнопок - это обычные кнопки (рис. 1). Их используют как заготовки. Если вы напишите в телеграм сообщение, соответствующее тексту на кнопке, то бот отреагирует, на сообщение так же как и на нажатие кнопки. Эти кнопки отображаются под полем ввода сообщения.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Рис. 1. Обычные кнопки (текстовые шаблоны)

# %% [markdown]
# Создадим обычную кнопку с текстом "Начать игру". Но сразу возникает вопрос как ее добавить, ведь любые кнопки в телеграм связаны с сообщениями и не могут быть сами по себе. Логичным выглядит добавление кнопки к приветственному сообщению, которое появляется после запуска бота или выполнения команды `\start`.

# %%
from aiogram.filters.command import Command
from aiogram import types
from aiogram.utils.keyboard import InlineKeyboardBuilder, ReplyKeyboardBuilder

# Хэндлер на команду /start
@dp.message(Command("start"))
async def cmd_start(message: types.Message):
    # Создаем сборщика клавиатур типа Reply
    builder = ReplyKeyboardBuilder()
    # Добавляем в сборщик одну кнопку
    builder.add(types.KeyboardButton(text="Начать игру"))
    # Прикрепляем кнопки к сообщению
    await message.answer("Добро пожаловать в квиз!", reply_markup=builder.as_markup(resize_keyboard=True))

# %% [markdown]
# Существует несколько методов добавления и расположения кнопок. Мы же будем использовать самый прогрессивный с использованием сборщика клавиатур (Keyboard Builder).
#
# **Для работы со сборщиком клавиатуры вам могут пригодиться следующие методы:**
# * add(`<KeyboardButton>`) — добавляет кнопку в память сборщика;
# * adjust(int1, int2, int3...) — делает строки по int1, int2, int3... кнопок;
# * as_markup() — возвращает готовый объект клавиатуры;
# * row(`<KeyboardButton1>`, `<KeyboardButton2>`,...) - аналогично `add` только позволяет добавлять сразу несколько кнопок в одну строку.
#
# Наши обычные кнопки называются еще как ReplyButton. По умолчанию кнопки получаются огромные и не красивые, чтобы этого избежать мы использовали `resize_keyboard=True`.

# %% [markdown]
# **А как нам отловить поведение на нажатие на кнопку?**
#
# Для этого мы используем все те же хендлеры, как для команды `\start`:

# %%
from aiogram import F

# Хэндлер на команды /quiz
@dp.message(F.text=="Начать игру")
@dp.message(Command("quiz"))
async def cmd_quiz(message: types.Message):
    # Отправляем новое сообщение без кнопок
    await message.answer(f"Давайте начнем квиз!")
    # Запускаем новый квиз
    await new_quiz(message)

# %% [markdown]
# В примере выше показано, что одну и ту же функцию можно использовать для двух разных хендлеров. В нашем случае функция `cmd_quiz` выполниться для команды `\quiz`, а также при нажатии на кнопку "Начать игру" или отправке боту сообщения "Начать игру".
#
# `F.text=="Начать игру"` - это так называемый Магический фильтр. В [документации](https://docs.aiogram.dev/en/dev-3.x/dispatcher/filters/magic_filters.html) aiogram, приведены все возможные варианты его использования. Нас же интересует, лишь фильтрация точного значения текста.
#
# **Важный момент**. Функция, получает от хендлера в качестве аргумента объект `message` типа `types.Message`. Это для нас важный объект и вся логика взаимодействия с телеграм ботом строиться на взаимодействии с перехваченным в хендлере сообщений. Поэтому не забывайте его указывать в качестве аргумента функции хендлера.

# %% [markdown]
# Идем дальше. Наша функция `cmd_quiz` заканчивается вызовом корутины `new_quiz`, которой мы в качестве параметра передаем наше перехваченное сообщение.
#
# Рассмотрим ее.

# %%
async def new_quiz(message):
    # получаем id пользователя, отправившего сообщение
    user_id = message.from_user.id
    # сбрасываем значение текущего индекса вопроса квиза в 0
    current_question_index = 0
    await update_quiz_index(user_id, current_question_index)

    # запрашиваем новый вопрос для квиза
    await get_question(message, user_id)

# %% [markdown]
# Здесь мы из сообщения узнаем пользователя, сбрасываем счетчик вопросов в 0, и запрашиваем асинхронно следующий вопрос для отправки пользователю в чат.

# %%
async def get_question(message, user_id):

    # Запрашиваем из базы текущий индекс для вопроса
    current_question_index = await get_quiz_index(user_id)
    # Получаем индекс правильного ответа для текущего вопроса
    correct_index = quiz_data[current_question_index]['correct_option']
    # Получаем список вариантов ответа для текущего вопроса
    opts = quiz_data[current_question_index]['options']

    # Функция генерации кнопок для текущего вопроса квиза
    # В качестве аргументов передаем варианты ответов и значение правильного ответа (не индекс!)
    kb = generate_options_keyboard(opts, opts[correct_index])
    # Отправляем в чат сообщение с вопросом, прикрепляем сгенерированные кнопки
    await message.answer(f"{quiz_data[current_question_index]['question']}", reply_markup=kb)

# %% [markdown]
# В результате получаем такое сообщение в виде вопроса викторины с кнопочками (InlineButton) вариантов ответа.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Больше информации по кнопкам смотрите [здесь](https://mastergroosha.github.io/aiogram-3-guide/buttons/)

# %% [markdown]
# Корутина `get_question()` не должна вызывать вопросов, так как работает с функциями описанными выше. За исключением функции `generate_options_keyboard()`, которую создает нам колбек-клавиатуру с вариантами ответов.

# %%
def generate_options_keyboard(answer_options, right_answer):
  # Создаем сборщика клавиатур типа Inline
    builder = InlineKeyboardBuilder()

    # В цикле создаем 4 Inline кнопки, а точнее Callback-кнопки
    for option in answer_options:
        builder.add(types.InlineKeyboardButton(
            # Текст на кнопках соответствует вариантам ответов
            text=option,
            # Присваиваем данные для колбэк запроса.
            # Если ответ верный сформируется колбэк-запрос с данными 'right_answer'
            # Если ответ неверный сформируется колбэк-запрос с данными 'wrong_answer'
            callback_data="right_answer" if option == right_answer else "wrong_answer")
        )

    # Выводим по одной кнопке в столбик
    builder.adjust(1)
    return builder.as_markup()

# %% [markdown]
# Механизм колбэков - очень мощный инструмент. Это и кнопки-реакции у постов (лайки), и меню у @BotFather и т.д. Суть механизма в том, что у колбэк-кнопок есть специальное значение (data), по которому ваше приложение опознаёт, что нажато и что надо сделать. И выбор правильного data очень важен! В нашем случае мы выбрали передавать в data только признак, правильным или нет, был ответ. В домашнем задании от вас будет требоваться усовершенствовать бот, в частности вывести ваш вариант ответа в чат. И вам придется подумать о правильности выбора data.

# %% [markdown]
# Ниже приведены два перехватчика колбэк запросов "right_answer" и "wrong_answer". Вы видите, что они очень похожи, в них даже есть много повторяющего кода, что по всем правилам программирования, стоит вынести в отдельные функции. Но мы намеренно этого не делаем, чтобы вы всю логику увидели в одном месте, в одном колбэке (в домашней работе, вы можете сделать это самостоятельно).

# %%
@dp.callback_query(F.data == "right_answer")
async def right_answer(callback: types.CallbackQuery):
    # редактируем текущее сообщение с целью убрать кнопки (reply_markup=None)
    await callback.bot.edit_message_reply_markup(
        chat_id=callback.from_user.id,
        message_id=callback.message.message_id,
        reply_markup=None
    )

    # Получение текущего вопроса для данного пользователя
    current_question_index = await get_quiz_index(callback.from_user.id)

    # Отправляем в чат сообщение, что ответ верный
    await callback.message.answer("Верно!")

    # Обновление номера текущего вопроса в базе данных
    current_question_index += 1
    await update_quiz_index(callback.from_user.id, current_question_index)

    # Проверяем достигнут ли конец квиза
    if current_question_index < len(quiz_data):
        # Следующий вопрос
        await get_question(callback.message, callback.from_user.id)
    else:
        # Уведомление об окончании квиза
        await callback.message.answer("Это был последний вопрос. Квиз завершен!")

# %%
@dp.callback_query(F.data == "wrong_answer")
async def wrong_answer(callback: types.CallbackQuery):
    # редактируем текущее сообщение с целью убрать кнопки (reply_markup=None)
    await callback.bot.edit_message_reply_markup(
        chat_id=callback.from_user.id,
        message_id=callback.message.message_id,
        reply_markup=None
    )

    # Получение текущего вопроса для данного пользователя
    current_question_index = await get_quiz_index(callback.from_user.id)

    correct_option = quiz_data[current_question_index]['correct_option']

    # Отправляем в чат сообщение об ошибке с указанием верного ответа
    await callback.message.answer(f"Неправильно. Правильный ответ: {quiz_data[current_question_index]['options'][correct_option]}")

    # Обновление номера текущего вопроса в базе данных
    current_question_index += 1
    await update_quiz_index(callback.from_user.id, current_question_index)

    # Проверяем достигнут ли конец квиза
    if current_question_index < len(quiz_data):
        # Следующий вопрос
        await get_question(callback.message, callback.from_user.id)
    else:
        # Уведомление об окончании квиза
        await callback.message.answer("Это был последний вопрос. Квиз завершен!")

# %% [markdown]
# **Из важных моментов**. Колбэк содержит message, но пользователя мы берем не из сообщения, как раньше (`callback.message.from_user.id`), а из самого колбэка (`callback.from_user.id`). Они будут отличаться!!!
#
# **Используйте только:** `callback.from_user.id`

# %% [markdown]
# Попробуйте теперь собрать все куски кода вместе и получить свой телеграм-бот. Запустите его в колабе. Если вам будет сложно это сделать самостоятельно, то вы можете подсматривать полный код бота ниже. Только помните, что в колаб уже есть свой запущенный event loop. Подставьте свой YOUR_BOT_TOKEN, полученный от Отца всех Ботов. И не забывайте устанавливать зависимости.

# %%
#@title Полный код бота для самоконтроля
import aiosqlite
import asyncio
import logging
from aiogram import Bot, Dispatcher, types
from aiogram.filters.command import Command
from aiogram.utils.keyboard import InlineKeyboardBuilder, ReplyKeyboardBuilder
from aiogram import F

# Включаем логирование, чтобы не пропустить важные сообщения
logging.basicConfig(level=logging.INFO)

# Замените "YOUR_BOT_TOKEN" на токен, который вы получили от BotFather
API_TOKEN = 'YOUR_BOT_TOKEN'

# Объект бота
bot = Bot(token=API_TOKEN)
# Диспетчер
dp = Dispatcher()

# Зададим имя базы данных
DB_NAME = 'quiz_bot.db'


# Структура квиза
quiz_data = [
    {
        'question': 'Что такое Python?',
        'options': ['Язык программирования', 'Тип данных', 'Музыкальный инструмент', 'Змея на английском'],
        'correct_option': 0
    },
    {
        'question': 'Какой тип данных используется для хранения целых чисел?',
        'options': ['int', 'float', 'str', 'natural'],
        'correct_option': 0
    },
    # Добавьте другие вопросы
]



def generate_options_keyboard(answer_options, right_answer):
    builder = InlineKeyboardBuilder()

    for option in answer_options:
        builder.add(types.InlineKeyboardButton(
            text=option,
            callback_data="right_answer" if option == right_answer else "wrong_answer")
        )

    builder.adjust(1)
    return builder.as_markup()


@dp.callback_query(F.data == "right_answer")
async def right_answer(callback: types.CallbackQuery):

    await callback.bot.edit_message_reply_markup(
        chat_id=callback.from_user.id,
        message_id=callback.message.message_id,
        reply_markup=None
    )

    await callback.message.answer("Верно!")
    current_question_index = await get_quiz_index(callback.from_user.id)
    # Обновление номера текущего вопроса в базе данных
    current_question_index += 1
    await update_quiz_index(callback.from_user.id, current_question_index)


    if current_question_index < len(quiz_data):
        await get_question(callback.message, callback.from_user.id)
    else:
        await callback.message.answer("Это был последний вопрос. Квиз завершен!")


@dp.callback_query(F.data == "wrong_answer")
async def wrong_answer(callback: types.CallbackQuery):
    await callback.bot.edit_message_reply_markup(
        chat_id=callback.from_user.id,
        message_id=callback.message.message_id,
        reply_markup=None
    )

    # Получение текущего вопроса из словаря состояний пользователя
    current_question_index = await get_quiz_index(callback.from_user.id)
    correct_option = quiz_data[current_question_index]['correct_option']

    await callback.message.answer(f"Неправильно. Правильный ответ: {quiz_data[current_question_index]['options'][correct_option]}")

    # Обновление номера текущего вопроса в базе данных
    current_question_index += 1
    await update_quiz_index(callback.from_user.id, current_question_index)


    if current_question_index < len(quiz_data):
        await get_question(callback.message, callback.from_user.id)
    else:
        await callback.message.answer("Это был последний вопрос. Квиз завершен!")


# Хэндлер на команду /start
@dp.message(Command("start"))
async def cmd_start(message: types.Message):
    builder = ReplyKeyboardBuilder()
    builder.add(types.KeyboardButton(text="Начать игру"))
    await message.answer("Добро пожаловать в квиз!", reply_markup=builder.as_markup(resize_keyboard=True))


async def get_question(message, user_id):

    # Получение текущего вопроса из словаря состояний пользователя
    current_question_index = await get_quiz_index(user_id)
    correct_index = quiz_data[current_question_index]['correct_option']
    opts = quiz_data[current_question_index]['options']
    kb = generate_options_keyboard(opts, opts[correct_index])
    await message.answer(f"{quiz_data[current_question_index]['question']}", reply_markup=kb)


async def new_quiz(message):
    user_id = message.from_user.id
    current_question_index = 0
    await update_quiz_index(user_id, current_question_index)
    await get_question(message, user_id)


async def get_quiz_index(user_id):
     # Подключаемся к базе данных
     async with aiosqlite.connect(DB_NAME) as db:
        # Получаем запись для заданного пользователя
        async with db.execute('SELECT question_index FROM quiz_state WHERE user_id = (?)', (user_id, )) as cursor:
            # Возвращаем результат
            results = await cursor.fetchone()
            if results is not None:
                return results[0]
            else:
                return 0


async def update_quiz_index(user_id, index):
    # Создаем соединение с базой данных (если она не существует, она будет создана)
    async with aiosqlite.connect(DB_NAME) as db:
        # Вставляем новую запись или заменяем ее, если с данным user_id уже существует
        await db.execute('INSERT OR REPLACE INTO quiz_state (user_id, question_index) VALUES (?, ?)', (user_id, index))
        # Сохраняем изменения
        await db.commit()


# Хэндлер на команду /quiz
@dp.message(F.text=="Начать игру")
@dp.message(Command("quiz"))
async def cmd_quiz(message: types.Message):

    await message.answer(f"Давайте начнем квиз!")
    await new_quiz(message)



async def create_table():
    # Создаем соединение с базой данных (если она не существует, она будет создана)
    async with aiosqlite.connect(DB_NAME) as db:
        # Создаем таблицу
        await db.execute('''CREATE TABLE IF NOT EXISTS quiz_state (user_id INTEGER PRIMARY KEY, question_index INTEGER)''')
        # Сохраняем изменения
        await db.commit()



# Запуск процесса поллинга новых апдейтов
async def main():

    # Запускаем создание таблицы базы данных
    await create_table()

    await dp.start_polling(bot)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# WARNING:aiogram.dispatcher:Received SIGINT signal

# %% [markdown]
# **Дополнительные ресурсы для ознакомления:**
#
# - Официальная документация [aiogram](https://docs.aiogram.dev/)
#
# - Руководство по [BotFather](https://core.telegram.org/bots#botfather)
#
# - Руководство по aiogram 3. Написало легко и довольно лаконично. Подходит в качестве успокающего [чтива](https://mastergroosha.github.io/aiogram-3-guide/) на ночь.

# %% [markdown]
# А теперь пора проявить себя в роли профессионального разработчика телеграм-ботов и сделать [домашнюю работу](https://colab.research.google.com/drive/1ylF61osqEgPqg4KgfmikbKMAyalhjBqv)
